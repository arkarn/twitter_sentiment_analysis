# Manika guides India to Table Tennis Gold at the CWG2018. Watch this detailed report
# More videos:… https://t.co/lfA3wupFdc
# Many congratulations to our Table tennis and Badminton team for winning Gold and creating history at #GC2018. Gold… https://t.co/0XVQ9vxhBD
# AI will play on both sides in the future of cyberwarfare https://t.co/o4xu3VowbB
# RT @PetroleumMin: Both deliberated on extending Motihari-Amlekhganj petroleum product pipeline upto Chitwan in Nepal. Min. @dpradhanbjp als…
# RT @abpnewshindi: BREAKING: उन्नाव गैंगरेप केस: पीड़ित के पिता के पोस्टमॉर्टम में बड़ा खुलासा, पिटाई की वजह से फट गयी थी आंत. डॉक्टरों ने…
# Roll-out of e-Way Bill system for Intra-State movement of goods in the States of Andhra Pradesh, Gujarat, Kerala, T… https://t.co/kMMc2pWHW9
# RT @htshowbiz: #RaaziTrailer has @aliaa08 as an Indian spy, married to a Pak soldier. Watch video https://t.co/7vkIAWrck9 https://t.co/TQxY…
# The full text of Mark Zuckerberg senate testimony is below. These are lots of words, but they are also important wo… https://t.co/OeTuLm2Yid

# %%
#!conda install ipyparallel
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %bg _ip.magic('run -i foo.py')
# Out:
# ERROR:root:Line magic function `%bg` not found.

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('python_tweets.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#python'])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1334             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1335         self._raise_ssl_error(self._ssl, result)
#    1336
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1148         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1149             raise WantReadError()
#    1150         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-895e40368c33> in <module>()
#      19
#      20 twitter_stream = Stream(auth, MyListener())
# ---> 21 twitter_stream.filter(track=['#python'])
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\http\client.py in read(self, amt)
#     446             # Amount is given, implement using readinto
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#     450         else:
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\http\client.py in readinto(self, b)
#     476
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#     480         if self.length is not None:
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     571         try:
#     572             while True:
# --> 573                 chunk_left = self._get_chunk_left()
#     574                 if chunk_left is None:
#     575                     return total_bytes
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     539                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     540             try:
# --> 541                 chunk_left = self._read_next_chunk_size()
#     542             except ValueError:
#     543                 raise IncompleteRead(b'')
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     499     def _read_next_chunk_size(self):
#     500         # Read the next chunk size from the file
# --> 501         line = self.fp.readline(_MAXLINE + 1)
#     502         if len(line) > _MAXLINE:
#     503             raise LineTooLong("chunk size")
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     287                 raise
#     288         except OpenSSL.SSL.WantReadError:
# --> 289             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     290             if not rd:
#     291                 raise timeout('The read operation timed out')
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# C:\Users\I341495\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:

# %%
3-4
# Out:
# -1

# %%
import tweepy
from tweepy import OAuthHandler
import json
import datetime as dt
import time
import os
import sys


'''
In order to use this script you should register a data-mining application
with Twitter.  Good instructions for doing so can be found here:
http://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/

After doing this you can copy and paste your unique consumer key,
consumer secret, access token, and access secret into the load_api()
function below.

The main() function can be run by executing the command: 
python twitter_search.py

I used Python 3 and tweepy version 3.5.0.  You will also need the other
packages imported above.
'''

def load_api():
    ''' Function that loads the twitter API after authorizing the user. '''
    consumer_key = 'GulHjuomtnilISVouWenn0t5O'
    consumer_secret = 'MqARy73MI0zC0TwHuA6ImqfNUVYrMKCya6zPKlCekSkM54BVni'
    access_token = '90368754-a4w8Et5lrZ572bQjnsj5BfvbYm0dNokHDAaoH0LNG'
    access_secret = 'dovJnqoWo7wBMetbfDpe7i9YyPGe5jsOXUoBbw907UJ3K'

    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    # load the twitter API via tweepy
    return tweepy.API(auth)

    
def tweet_search(api, query, max_tweets, max_id, since_id, geocode):
    ''' Function that takes in a search string 'query', the maximum
        number of tweets 'max_tweets', and the minimum (i.e., starting)
        tweet id. It returns a list of tweepy.models.Status objects. '''

    searched_tweets = []
    while len(searched_tweets) < max_tweets:
        remaining_tweets = max_tweets - len(searched_tweets)
        try:
            print('trying')
            new_tweets = api.search(q=query, count=remaining_tweets,
                                    since_id=str(since_id),
				                    max_id=str(max_id-1))
#                                    geocode=geocode)
            print('found',len(new_tweets),'tweets')
            if not new_tweets:
                print('no tweets found')
                break
            searched_tweets.extend(new_tweets)
            max_id = new_tweets[-1].id
        except tweepy.TweepError:
            print('exception raised, waiting 15 minutes')
            print('(until:', dt.datetime.now()+dt.timedelta(minutes=15), ')')
            time.sleep(15*60)
            break # stop the loop
    return searched_tweets, max_id


def get_tweet_id(api, date='', days_ago=9, query='a'):
    ''' Function that gets the ID of a tweet. This ID can then be
        used as a 'starting point' from which to search. The query is
        required and has been set to a commonly used word by default.
        The variable 'days_ago' has been initialized to the maximum
        amount we are able to search back in time (9).'''

    if date:
        # return an ID from the start of the given day
        td = date + dt.timedelta(days=1)
        tweet_date = '{0}-{1:0>2}-{2:0>2}'.format(td.year, td.month, td.day)
        tweet = api.search(q=query, count=1, until=tweet_date)
    else:
        # return an ID from __ days ago
        td = dt.datetime.now() - dt.timedelta(days=days_ago)
        tweet_date = '{0}-{1:0>2}-{2:0>2}'.format(td.year, td.month, td.day)
        # get list of up to 10 tweets
        tweet = api.search(q=query, count=10, until=tweet_date)
        print('search limit (start/stop):',tweet[0].created_at)
        # return the id of the first tweet in the list
        return tweet[0].id


def write_tweets(tweets, filename):
    ''' Function that appends tweets to a file. '''

    with open(filename, 'a') as f:
        for tweet in tweets:
            json.dump(tweet._json, f)
            f.write('\n')


def main():
    ''' This is a script that continuously searches for tweets
        that were created over a given number of days. The search
        dates and search phrase can be changed below. '''



    ''' search variables: '''
    search_phrases = ['sap', 'saplabs']
    time_limit = 1                           # runtime limit in hours
    max_tweets = 10                          # number of tweets per search (will be
                                               # iterated over) - maximum is 100
    min_days_old, max_days_old = 1, 0          # search limits e.g., from 7 to 8
                                               # gives current weekday from last week,
                                               # min_days_old=0 will search from right now
    USA = '39.8,-95.583068847656,2500km'       # this geocode includes nearly all American
                                               # states (and a large portion of Canada)
    

    # loop over search items,
    # creating a new file for each
    for search_phrase in search_phrases:

        print('Search phrase =', search_phrase)

        ''' other variables '''
        name = search_phrase.split()[0]
        json_file_root = name + '/'  + name
        os.makedirs(os.path.dirname(json_file_root), exist_ok=True)
        read_IDs = False
        
        # open a file in which to store the tweets
        if max_days_old - min_days_old == 1:
            d = dt.datetime.now() - dt.timedelta(days=min_days_old)
            day = '{0}-{1:0>2}-{2:0>2}'.format(d.year, d.month, d.day)
        else:
            d1 = dt.datetime.now() - dt.timedelta(days=max_days_old-1)
            d2 = dt.datetime.now() - dt.timedelta(days=min_days_old)
            day = '{0}-{1:0>2}-{2:0>2}_to_{3}-{4:0>2}-{5:0>2}'.format(
                  d1.year, d1.month, d1.day, d2.year, d2.month, d2.day)
        json_file = json_file_root + '_' + day + '.json'
        if os.path.isfile(json_file):
            print('Appending tweets to file named: ',json_file)
            read_IDs = True
        
        # authorize and load the twitter API
        api = load_api()
        
        # set the 'starting point' ID for tweet collection
        if read_IDs:
            # open the json file and get the latest tweet ID
            with open(json_file, 'r') as f:
                lines = f.readlines()
                max_id = json.loads(lines[-1])['id']
                print('Searching from the bottom ID in file')
        else:
            # get the ID of a tweet that is min_days_old
            if min_days_old == 0:
                max_id = -1
            else:
                max_id = get_tweet_id(api, days_ago=(min_days_old-1))
        # set the smallest ID to search for
        since_id = get_tweet_id(api, days_ago=(max_days_old-1))
        print('max id (starting point) =', max_id)
        print('since id (ending point) =', since_id)
        


        ''' tweet gathering loop  '''
        start = dt.datetime.now()
        end = start + dt.timedelta(hours=time_limit)
        count, exitcount = 0, 0
        while dt.datetime.now() < end:
            count += 1
            print('count =',count)
            # collect tweets and update max_id
            tweets, max_id = tweet_search(api, search_phrase, max_tweets,
                                          max_id=max_id, since_id=since_id,
                                          geocode=USA)
            # write tweets to file in JSON format
            if tweets:
                write_tweets(tweets, json_file)
                exitcount = 0
            else:
                exitcount += 1
                if exitcount == 3:
                    if search_phrase == search_phrases[-1]:
                        sys.exit('Maximum number of empty tweet strings reached - exiting')
                    else:
                        print('Maximum number of empty tweet strings reached - breaking')
                        break


if __name__ == "__main__":
    main()
# Out:
# Search phrase = sap
# search limit (start/stop): 2018-01-12 23:59:59
# search limit (start/stop): 2018-01-13 16:51:44
# max id (starting point) = 951967024540016641
# since id (ending point) = 952221637553938434
# count = 1
# trying
# exception raised, waiting 15 minutes
# (until: 2018-01-13 22:37:01.338848 )

# %%
import json
 
tweet_files = ['tweetsdir/stream__bitcoin.json']
tweets = []
for file in tweet_files:
    with open(file, 'r') as f:
        for line in f.readlines():
            tweets.append(json.loads(line))
            
def populate_tweet_df(tweets):
    df = pd.DataFrame()
 
    df['text'] = list(map(lambda tweet: tweet['text'], tweets))
 
    df['location'] = list(map(lambda tweet: tweet['user']['location'], tweets))
 
    df['country_code'] = list(map(lambda tweet: tweet['place']['country_code']
                                  if tweet['place'] != None else '', tweets))
 
    df['long'] = list(map(lambda tweet: tweet['coordinates']['coordinates'][0]
                        if tweet['coordinates'] != None else 'NaN', tweets))
 
    df['latt'] = list(map(lambda tweet: tweet['coordinates']['coordinates'][1]
                        if tweet['coordinates'] != None else 'NaN', tweets))
 
    return df
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-f86c5dfb6985> in <module>()
#       6     with open(file, 'r') as f:
#       7         for line in f.readlines():
# ----> 8             tweets.append(json.loads(line))
#       9
#      10 def populate_tweet_df(tweets):
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)

# %%
1+2
# Out:
# 3

# %%
from mpl_toolkits.basemap import Basemap
 
# plot the blank world map
my_map = Basemap(projection='merc', lat_0=50, lon_0=-100,
                     resolution = 'l', area_thresh = 5000.0,
                     llcrnrlon=-140, llcrnrlat=-55,
                     urcrnrlon=160, urcrnrlat=70)
# set resolution='h' for high quality
 
# draw elements onto the world map
my_map.drawcountries()
#my_map.drawstates()
my_map.drawcoastlines(antialiased=False,
                      linewidth=0.005)
 
# add coordinates as red dots
longs = list(df.loc[(df.long != 'NaN')].long)
latts = list(df.loc[df.latt != 'NaN'].latt)
x, y = my_map(longs, latts)
my_map.plot(x, y, 'ro', markersize=6, alpha=0.5)
 
plt.show()

# %%
# To run this code, first edit config.py with your configuration, then:
#
# mkdir data
# python twitter_stream_download.py -q apple -d data
# 
# It will produce the list of tweets for the query "apple" 
# in the file data/stream_apple.json

import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import argparse
import string

import json

def get_parser():
    """Get parser for command line arguments."""
    parser = argparse.ArgumentParser(description="Twitter Downloader")
    parser.add_argument("-q",
                        "--query",
                        dest="query",
                        help="Query/Filter",
                        default='-')
    parser.add_argument("-d",
                        "--data-dir",
                        dest="data_dir",
                        help="Output/Data Directory")
    return parser


class MyListener(StreamListener):
    """Custom StreamListener for streaming data."""

    def __init__(self, data_dir, query):
        query_fname = format_filename(query)
        self.outfile = "%s/stream_%s.json" % (data_dir, query_fname)

    def on_data(self, data):
        try:
            with open(self.outfile, 'a') as f:
                print("camehere")
                f.write(data)
                print(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
            time.sleep(5)
        return True

    def on_error(self, status):
        print(status)
        return True


def format_filename(fname):
    """Convert file name into a safe string.
    Arguments:
        fname -- the file name to convert
    Return:
        String -- converted file name
    """
    return ''.join(convert_valid(one_char) for one_char in fname)


def convert_valid(one_char):
    """Convert a character into '_' if invalid.
    Arguments:
        one_char -- the char to convert
    Return:
        Character -- converted char
    """
    valid_chars = "-_.%s%s" % (string.ascii_letters, string.digits)
    if one_char in valid_chars:
        return one_char
    else:
        return '_'

@classmethod
def parse(cls, api, raw):
    status = cls.first_parse(api, raw)
    setattr(status, 'json', json.dumps(raw))
    return status

if __name__ == '__main__':
    #parser = get_parser()
    #args = parser.parse_args()
    consumer_key = 'GulHjuomtnilISVouWenn0t5O'
    consumer_secret = 'MqARy73MI0zC0TwHuA6ImqfNUVYrMKCya6zPKlCekSkM54BVni'
    access_token = '90368754-a4w8Et5lrZ572bQjnsj5BfvbYm0dNokHDAaoH0LNG'
    access_secret = 'dovJnqoWo7wBMetbfDpe7i9YyPGe5jsOXUoBbw907UJ3K'
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    api = tweepy.API(auth)
    myquery = '#bitcoin'
    twitter_stream = Stream(auth, MyListener('tweetsdir', myquery))
    twitter_stream.filter(track=[myquery])
# Out:
# camehere
# {"created_at":"Sat Jan 13 17:32:12 +0000 2018","id":952231823056228352,"id_str":"952231823056228352","text":"50 #Crypto Trading &amp; #Investing Lessons From The Past 5 Years by Chris Dunn https:\/\/t.co\/dEhCTKt8sf #bitcoin #Ethereum","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":945599188640952320,"id_str":"945599188640952320","name":"CryptoValueInvestor","screen_name":"CryptoValueInv","location":"Landing Mars","url":null,"description":"Cryptocurrency investor, trader, hodler. Committed to master TA! Learn and follow the trend.","translator_type":"none","protected":false,"verified":false,"followers_count":17,"friends_count":47,"listed_count":1,"favourites_count":48,"statuses_count":53,"created_at":"Tue Dec 26 10:16:29 +0000 2017","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"fi","contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/945616104021549056\/TyBath0n_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/945616104021549056\/TyBath0n_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/945599188640952320\/1514287535","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[{"text":"Crypto","indices":[3,10]},{"text":"Investing","indices":[25,35]},{"text":"bitcoin","indices":[104,112]},{"text":"Ethereum","indices":[113,122]}],"urls":[{"url":"https:\/\/t.co\/dEhCTKt8sf","expanded_url":"https:\/\/www.youtube.com\/watch?v=WowL_48p86A","display_url":"youtube.com\/watch?v=WowL_4\u2026","indices":[80,103]}],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en","timestamp_ms":"1515864732885"}
#
# camehere
# {"created_at":"Sat Jan 13 17:32:14 +0000 2018","id":952231827917496321,"id_str":"952231827917496321","text":"January 13, 2018 at 05:32PM#bitcoin furure millionaires check this out https:\/\/t.co\/zcfviBsQpW #bitcoinprice #buybitcoin #bitcoinnews #BTC","source":"\u003ca href=\"https:\/\/ifttt.com\" rel=\"nofollow\"\u003eIFTTT\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id
utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/786798915274219522\/lFhx54VC_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/786798915274219522\/lFhx54VC_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/785214387007041536\/1483224175","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coo ...
#
# camehere
# {"created_at":"Sat Jan 13 17:32:21 +0000 2018","id":952231857390800896,"id_str":"952231857390800896","text":"RT @MoonLite_ICO: Visit https:\/\/t.co\/YPI8pk7YDq to see our White papers and all there is to know about our project. See what we do and how\u2026","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":3434123883,"id_str":"3434123883","name":"Veronika Semenova","screen_name":"marcusbrooks132","location":"\u041c\u043e\u0441\u043a\u0432\u0430, \u0420\u043e\u0441\u0441\u0438\u044f","url":null,"description":"#\u0412\u0437\u0430\u0438\u043c\u043d\u044b\u0439\u0424\u043e\u043b\u043b\u043e\u0432\u0438\u043d\u0433, \n#\u0427\u0438\u0442\u0430\u044e\u0412\u0437\u0430\u0438\u043c\u043d\u043e, \n#\u0432\u0437\u0430\u0438\u043c\u043d\u043e\u0447\u0438\u0442\u0430\u044e, \n#\u0427\u0438\u0442\u0430\u0439\u041c\u0435\u043d\u044f\u0410\u044f\u0422\u0435\u0431\u044f, \n#\u0432\u0437\u0430\u0438\u043c\u043d\u043e\u0444\u043e\u043b\u043b\u043e\u0432\u043b\u044e, \n#followback","translator_type":"none","protected":false,"verified":false,"followers_count":4117,"friends_count":4813,"listed_count":52,"favourites_count":5127,"statuses_count":12693,"created_at":"Fri Aug 21 13:16:36 +0000 2015","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"ru","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"981CEB","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/887458497079779332\/xseYr9iX_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/887458497079779332\/xseYr9iX_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/3434123883\/1443799766","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Fri Jan 12 10:00:42 +0000 2018","id":951755808848711680,"id_str":"951755808848711680","text":"Visit https:\/\/t.co\/YPI8pk7YDq to see our White papers and all there is to know about our project. See what we do an\u2026 https:\/\/t.co\/0194yHELCC","source":"\u003ca href=\"http:\/\/www.hootsuite.com\" rel=\"nofollow\"\u003eHootsuite\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":930699274278629376,"id_str":"930699274278629376","name":"MoonLite_ICO","screen_name":"MoonLite_ICO","location":"London, England | Pretoria, South Africa","url":"http:\/\/www.moonlite.io","description":"The MoonLite Project aims to add value to all token holders by employing the latest technology, in the most efficient manner, and run by the most suitable team.","translator_type":"none","protected":false,"verified":false,"followers_count":485,"friends_count":91,"listed_count":14,"favourites_count":10,"statuses_count":91,"created_at":"Wed Nov 15 07:29:33 +0000 2017","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"AC892F","profile_s ...
#
# camehere
# ...
#
# camehere
# {"created_at":"Sat Jan 13 17:33:00 +0000 2018","id":952232023816658944,"id_str":"952232023816658944","text":"Chip Makers Aren\u2019t Stacking Bets on Cryptocurrencies #crypto #bitcoin https:\/\/t.co\/tTu8S4iokN","source":"\u003ca href=\"http:\/\/bufferapp.com\" rel=\"nofollow\"\u003eBuffer\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":819918647388835841,"id_str":"819918647388835841","name":"Aaron Taylor","screen_name":"AaronFinCrim","location":"London, England","url":"http:\/\/FinancialCrimes.com","description":"Partner at Financial Crimes Consulting Group @FinCrimes #FinCrimes #FinancialCrimes #AML #AntiMoneyLaundering #Fraud #Cybersecurity #Compliance","translator_type":"none","protected":false,"verified":false,"followers_count":286,"friends_count":199,"listed_count":16,"favourites_count":0,"statuses_count":712,"created_at":"Fri Jan 13 14:46:53 +0000 2017","utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"6098BD","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/820134808479109120\/UQ7a_qLr_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/820134808479109120\/UQ7a_qLr_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/819918647388835841\/1486194943","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[{"text":"crypto","indices":[53,60]},{"text":"bitcoin","indices":[61,69]}],"urls":[{"url":"https:\/\/t.co\/tTu8S4iokN","expanded_url":"http:\/\/on.wsj.com\/2Dj4Qk7","display_url":"on.wsj.com\/2Dj4Qk7","indices":[70,93]}],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en","timestamp_ms":"1515864780750"}
#
# camehere
# {"created_at":"Sat Jan 13 17:33:00 +0000 2018","id":952232024080769025,"id_str":"952232024080769025","text":"RT @Cryptorian2017: #ImNeverGoingTo FALL VICTIM TO THE FUD BEING SPREAD BY THE 1%. They will make headlines everyday about Countries \u201cbanni\u2026","source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eMobile Web (M2)\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":945301639233118208,"id_str":"945301639233118208","name":"Amlan Fubuki","screen_name":"AmlanFubuki","location":"Assam, North East, India","url":null,"description":"Edm Maniac","translator_type":"none","protected":false,"verified":false,"followers_count":89,"friends_count":103,"listed_count":1,"favourites_count":2209,"statuses_count":658,"created_at":"Mon Dec 25 14:34:08 +0000 2017","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en-gb","contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/945303442574032897\/nPKAaChV_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/945303442574032897\/nPKAaChV_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/945301639233118208\/1514212891","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Sat Jan 13 16:32:03 +0000 2018","id":952216685464948737,"id_str":"952216685464948737","text":"#ImNeverGoingTo FALL VICTIM TO THE FUD BEING SPREAD BY THE 1%. They will make headlines everyday about Countries \u201cb\u2026 https:\/\/t.co\/FZovK5OgW9","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":945880798959464449,"id_str":"945880798959464449","name":"CryptoPAC","screen_name":"Cryptorian2017","location":"Earth","url":null,"description":"#PacCoinArmy $PAC #PacCoin #PacLyfe #cryptocurrency #cryptorians #PowerToThePeople #PTTP","translator_type":"none","protected":false,"verified":false,"followers_count":167,"friends_count":70,"listed_count":0,"favourites_count":267,"statuses_count":252,"created_at":"Wed Dec 27 04:55:30 +0000 2017","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/950948137199439873\/5BFxeI08_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/950948137199439873\/5BFxeI08_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/945880798959464449\/1515123577","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"extended_tweet":{"full_text":"#ImNeverGoingTo FALL VICTIM TO THE FUD BEING SPREAD BY THE 1%. They will make headlines everyday about Countries \u201cbanning\u20 ...
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1624             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1625         self._raise_ssl_error(self._ssl, result)
#    1626
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1430         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1431             raise WantReadError()
#    1432         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-56b747912778> in <module>()
#      97     myquery = '#bitcoin'
#      98     twitter_stream = Stream(auth, MyListener('tweetsdir', myquery))
# ---> 99     twitter_stream.filter(track=[myquery])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:
